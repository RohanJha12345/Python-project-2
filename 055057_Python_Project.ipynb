# %% [markdown]
# # <span style="color:blue">**📊 Project Report on Imports and Exports Data Analysis 📈**</span>
#
# ---
#
# ![Imports](https://upload.wikimedia.org/wikipedia/commons/thumb/5/50/Export_icon.png/120px-Export_icon.png) ![Exports](https://upload.wikimedia.org/wikipedia/commons/thumb/5/5b/Import_icon.png/120px-Import_icon.png)
#
# ---
# ---
#
# # __Project Information__
#
# * **Project Title**:Extensive   Imports and Exports Data Analysis
# * **Student Name**: Rohan Jha
# * **Enrollment Number**: 055057
# * **Project Information**: <span style="color:red">The **Imports and Exports Data Analysis** project delves into a comprehensive review of global trade patterns, providing crucial insights into the dynamics between different countries, products, and regions. I focused on identifying trends, key trading partners, and the economic impacts of these trades on the global market.</span>
# ## __Description of Data__
#
# ### 1. Data Source & Size:
# * **Source**: The dataset for this project was obtained from [Kaggle](https://www.kaggle.com/datasets/chakilamvishwas/imports-exports-15000).
# * **Size**: 15,000 records with 16 variables (2.69 MB)
#
# ### 2. Data Type:
# * This is a **Cross-sectional dataset**, capturing transactional data at a specific point in time.
#
# ### 3. Data Dimension:
# * **Number of Variables**: 16
# * **Number of Observations**: 15,000
#
# ### 4. Data Variable Type:
#
# * **Text Variables**:
#     * Transaction_ID, Country, Product, Import_Export, Date, Category, Port, Shipping_Method, Supplier, Customer, Payment_Terms
# * **Number Variables**:
#     * **Integer**: Quantity, Customs_Code, Invoice_Number
#     * **Decimal**: Value, Weight
#
# ### 5. Data Variable Category:
#
# Identifying Categorical (Nominal & Ordinal) and Non-Categorical Data.
#
# | Sr. No. | Data Variable      | Category                             |
# |:-------:|:-------------------|:-------------------------------------|
# | 1.      | Transaction ID      | Index (used for identifying each transaction) |
# | 2.      | Country             | Categorical {Nominal}               |
# | 3.      | Product             | Categorical {Nominal}               |
# | 4.      | Import Export       | Categorical {Nominal}               |
# | 5.      | Quantity            | Numerical                           |
# | 6.      | Value               | Numerical                           |
# | 7.      | Category            | Categorical {Nominal}               |
# | 8.      | Port                | Categorical {Nominal}               |
# | 9.      | Customs Code        | Numerical                           |
# | 10.     | Weight              | Numerical                           |
# | 11.     | Shipping Method     | Categorical {Nominal}               |
# | 12.     | Supplier            | Categorical {Nominal}               |
# | 13.     | Customer            | Categorical {Nominal}               |
# | 14.     | Invoice Number      | Index (used for identifying each transaction) |
# | 15.     | Payment Terms       | Categorical {Nominal}               |
#
#
#
# ---

# %% [markdown]
# ### Project Objectives | Problem Statements
#
# **Objective**: The primary objective of this project is to analyze import and export data across various countries, products, and shipping methods. The goal is to identify trends and patterns that can inform decision-making processes for optimizing international trade operations.
#
# **Problem Statements**:
# 1. What are the key trends in the import and export of different product categories across countries?
# 2. How do factors such as shipping methods, customs regulations, and payment terms impact trade volume and value?
# 3. What are the differences in trade patterns across various countries and products?
# 4. Can the data provide insights into optimizing logistics for more efficient trade operations?
#
# ---
#
# ### Analysis of Data
#
# 1. **Dataset Overview**:
#    - The dataset consists of several columns such as `Country`, `Product`, `Import_Export`, `Quantity`, `Value`, `Date`, `Category`, `Port`, `Customs_Code`, `Weight`, `Shipping_Method`, `Supplier`, `Customer`, `Invoice_Number`, and `Payment_Terms`.
#    - It captures trade data from multiple countries, highlighting imports and exports of various products, their quantities, values, and shipment details.
#
# 2. **Random Sample Extraction**:
#    - A random sample of 3001 rows can be extracted for deeper analysis to get more manageable and representative insights.
#
# 3. **Key Columns for Analysis**:
#    - `Import_Export`: To differentiate between import and export activities.
#    - `Country`: To observe trade patterns by country.
#    - `Product` and `Category`: To analyze specific product trends.
#    - `Quantity`, `Value`, `Weight`: For understanding the volume and value of trade.
#    - `Shipping_Method` and `Port`: To explore logistics and shipping efficiency.
#
# ---
#
# ### Observations | Findings
#
# 1. **Country-wise Trends**:
#    - The dataset captures trade across diverse countries like Colombia, Chile, Turkey, and Finland. Each country has varying patterns of imports and exports across product categories such as Machinery, Clothing, Electronics, and Furniture.
#
# 2. **Shipping Method Preferences**:
#    - Air transport appears to be a commonly used shipping method, which could indicate a preference for speed in trade transactions, although this may also increase costs.
#
# 3. **Product Categories and Trade Volume**:
#    - Categories such as Machinery, Electronics, and Clothing dominate both in terms of trade quantity and value, suggesting a focus on high-demand goods across countries.
#
# 4. **Payment Terms**:
#    - Payment methods like "Cash on Delivery" and "Prepaid" are frequently used, which may reflect trust issues or varying market practices in different regions.
#
# ---
#
# ### Managerial Insights | Recommendations
#
# 1. **Optimize Shipping Methods**:
#    - A detailed analysis of shipping methods should be conducted to determine if alternatives such as sea or rail transport could reduce costs without significantly affecting delivery times.
#
# 2. **Strategic Partnerships with Suppliers**:
#    - Companies should consider forming strategic partnerships with suppliers who demonstrate efficiency in shipping high-value or high-quantity products to minimize delays and costs.
#
# 3. **Focus on High-Value Categories**:
#    - Companies involved in trade should prioritize categories such as Electronics and Machinery, which have higher values per shipment. This focus could yield greater profitability and operational efficiency.
#
# 4. **Risk Mitigation via Payment Terms**:
#    - To reduce financial risks, companies should analyze the impact of various payment terms, possibly promoting prepaid terms in regions with higher risk profiles to secure payments upfront.

# %%
# Import Relevant Python Libraries.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# %%
#Import dataset
df=pd.read_csv(r"D:\FSM Documents\Python\Python Project 1\Imports_Exports_Dataset.csv")
df
# Out:
#                              Transaction_ID           Country    Product  \
# 0      e3e70682-c209-4cac-a29f-6fbed82c07cd          Colombia   describe
# 1      f728b4fa-4248-4e3a-8a5d-2f346baa9455             Chile  president
# 2      eb1167b3-67a9-4378-bc65-c1e582e2e662            Turkey        far
# 3      f7c1bd87-4da5-4709-9471-3d60c8a70639  Christmas Island     agency
# 4      e443df78-9558-467f-9ba9-1faf7a024204           Finland     policy
# ...                                     ...               ...        ...
# 14995  48df15a8-0823-4964-8c16-eddf2756f382  Marshall Islands        not
# 14996  31106617-94a6-4646-a001-5e7bd45abc26           Bermuda        air
# 14997  ee485839-fbde-4ced-af18-d98f5e863081          Tanzania       show
# 14998  5acd54aa-ec8c-4055-be8b-a447861a471c            Tuvalu         TV
# 14999  5cc039d0-a052-41fd-bfbb-c9f60c4565ac   North Macedonia       year
#
#       Import_Export  Quantity    Value        Date     Category  \
# 0            Export      1979  9506.57  07-12-2023    Machinery
# 1            Export      5763  7100.91  04-04-2023     Clothing
# 2            Import      5740  2450.34  21-08-2024  Electronics
# 3            Export      2592  7226.42  09-05-2022    Furniture
# 4            Export      2622  2817.29  03-04-2023  Electronics
# ...             ...       ...      ...         ...          ...
# 14995        Export      2860  2055.19  09-07-2024    Furniture
# 14996        Export      2443  6407.06  18-06-2024    Furniture
# 14997        Export      1702  9918.29  30-04-2020         Toys
# 14998        Export      8108  9288.57  29-04-2021     Clothing
# 14999        Import      5635   561.33  25-12-2019     Clothing
#
#                      Port  Customs_Code   Weight Shipping_Method  \
# 0              Robertbury        620537  4248.65             Air
# 1                Shahport        927600  4340.81             Air
# 2        South Joshuatown        299258  4538.41             Air
# 3                Adamfort        996084  4886.14             Air
# 4               Juliebury        555981  4406.74             Air
# ...                   ...           ...      ...             ...
# 14995     South Karenfort        393463  4120.35            Land
# 14996         Jeffreyside        484143  1832.71             Air
# 14997  North Meganborough        354935  4203.52            Land
# 14998           Villafurt        234296  1597.72            Land
# 14999           West Gary        766709  2913.82             Air
#
#                               Supplier        Customer  Invoice_Number  \
# 0      Garrison, Hubbard and Hendricks       Seth Hall        21000294
# 1                            Webb-Mack   Kimberly Ryan        88738432
# 2            Mendez, Jones and Johnson      Ryan Silva        89922099
# 3                      Schroeder-Smith      Jacob Gray        63216265
# 4                        Zimmerman LLC    Amy Stephens        94600248
# ...                                ...             ...             ...
# 14995                      Smith-Lewis   Darlene Davis        29605073
# 14996                      Jones Group      John Ramos        39044695
# 14997                    Barnes-Romero  Rebecca Phelps        78492040
# 14998       Smith, Allison and Bennett     Scott Yates        20799602
# 14999                    Fleming-Miles    Steven Young        79237293
#
#           Payment_Terms
# 0      Cash on Delivery
# 1               Prepaid
# 2               Prepaid
# 3                Net 60
# 4      Cash on Delivery
# ...                 ...
# 14995            Net 60
# 14996  Cash on Delivery
# 14997            Net 30
# 14998  Cash on Delivery
# 14999            Net 30
#
# [15000 rows x 16 columns]

# %%
#Random Sample from the dataset
sdf = df.sample(n = 3001, random_state = 55057)
sdf.head()
# Out:
#                              Transaction_ID            Country    Product  \
# 10594  ab1835e0-4073-4471-b726-24d496e6d77a         Montenegro     become
# 6393   44876daa-84d8-4ce5-b110-e56b787079cd         Uzbekistan       well
# 13119  2209bc3e-bcba-48ef-8771-ef3354b5231a  Wallis and Futuna  treatment
# 13902  74841903-8521-4382-a669-8a2731922c9d           Paraguay       sign
# 13569  a5487a73-0324-4a63-b1a0-039f2d248033           Pakistan   specific
#
#       Import_Export  Quantity    Value        Date   Category  \
# 10594        Export      2327  6895.52  08-01-2021       Toys
# 6393         Import      9515  4468.59  13-02-2023  Machinery
# 13119        Import      6794  4789.81  13-05-2020  Furniture
# 13902        Import      2791  9728.56  07-08-2021  Machinery
# 13569        Import      6495  9419.58  04-06-2024  Furniture
#
#                    Port  Customs_Code   Weight Shipping_Method  \
# 10594       Crystalbury        885783   278.96             Air
# 6393    East Frankshire        334712   886.73             Sea
# 13119  South Scottville        949678  1999.40             Sea
# 13902      Gilbertmouth        721076   380.50             Sea
# 13569         Welchside        350637  3711.72            Land
#
#                 Supplier         Customer  Invoice_Number     Payment_Terms
# 10594  Gonzales-Guerrero   Kelly Williams        79301173            Net 60
# 6393      Scott and Sons  Trevor Williams        12970182           Prepaid
# 13119  Mendoza-Armstrong  Mary Mclaughlin        34445198  Cash on Delivery
# 13902    Maxwell-Ramirez     Anne Johnson        33065268  Cash on Delivery
# 13569         Thomas Ltd     Nicole Hardy        72031254            Net 30

# %%
# Dimensions of the data
dimensions = sdf.shape
print('No. of rows in the data are:',dimensions[0])
print('No. of columns in the data are:',dimensions[1])
# Out:
# No. of rows in the data are: 3001
# No. of columns in the data are: 16

# %%
sdf.columns
# Sample Data Information.
sdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3001 entries, 10594 to 11486
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Transaction_ID   3001 non-null   object
#  1   Country          3001 non-null   object
#  2   Product          3001 non-null   object
#  3   Import_Export    3001 non-null   object
#  4   Quantity         3001 non-null   int64
#  5   Value            3001 non-null   float64
#  6   Date             3001 non-null   object
#  7   Category         3001 non-null   object
#  8   Port             3001 non-null   object
#  9   Customs_Code     3001 non-null   int64
#  10  Weight           3001 non-null   float64
#  11  Shipping_Method  3001 non-null   object
#  12  Supplier         3001 non-null   object
#  13  Customer         3001 non-null   object
#  14  Invoice_Number   3001 non-null   int64
#  15  Payment_Terms    3001 non-null   object
# dtypes: float64(2), int64(3), object(11)
# memory usage: 398.6+ KB

# %% [markdown]
# # 📊 **Statistical Analysis of Non-Categorical Data**

# %%
# Extracting non-categorical (numerical) variables
numerical_columns = sdf.select_dtypes(include=[np.number]).columns.tolist()

# Display the numerical columns
print("Non-Categorical Variables:", numerical_columns)
# Out:
# Non-Categorical Variables: ['Quantity', 'Value', 'Customs_Code', 'Weight', 'Invoice_Number']

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import skew, kurtosis

# Non-categorical columns
numeric_columns = ['Quantity', 'Value', 'Weight']

# 1. Descriptive statistics
desc_stats = sdf[numeric_columns].describe()
print("Descriptive Statistics:\n", desc_stats)

# 2. Correlation matrix
correlation_matrix = sdf[numeric_columns].corr()
print("\nCorrelation Matrix:\n", correlation_matrix)

# 3. Variance
variance = sdf[numeric_columns].var()
print("\nVariance:\n", variance)

# 4. Skewness
skewness = sdf[numeric_columns].apply(skew)
print("\nSkewness:\n", skewness)

# 5. Kurtosis
kurt = sdf[numeric_columns].apply(kurtosis)
print("\nKurtosis:\n", kurt)

# 6. Histograms for numerical columns
plt.figure(figsize=(15, 5))
sdf[numeric_columns].hist(bins=30, layout=(1, 3), figsize=(15, 5))
plt.suptitle('Distribution of Quantity, Value, and Weight')
plt.show()

# 7. Boxplot for numerical columns
plt.figure(figsize=(15, 5))
sns.boxplot(data=sdf[numeric_columns])
plt.title('Boxplot of Quantity, Value, and Weight')
plt.show()

# 8. Scatter matrix for pairwise relationships
pd.plotting.scatter_matrix(sdf[numeric_columns], figsize=(10, 10))
plt.suptitle('Scatter Matrix of Numerical Variables')
plt.show()
# Out:
# Descriptive Statistics:
#            Quantity        Value       Weight
# count  3001.000000  3001.000000  3001.000000
# mean   4906.533156  5069.381919  2535.967634
# std    2853.168243  2884.475494  1437.061216
# min       1.000000   103.030000     2.860000
# 25%    2362.000000  2571.760000  1303.910000
# 50%    4922.000000  5102.290000  2504.570000
# 75%    7343.000000  7539.840000  3796.340000
# max    9995.000000  9999.130000  4999.930000
#
# Correlation Matrix:
#            Quantity     Value    Weight
# Quantity  1.000000 -0.016366  0.006099
# Value    -0.016366  1.000000  0.019131
# Weight    0.006099  0.019131  1.000000
#
# Variance:
#  Quantity    8.140569e+06
# Value       8.320199e+06
# Weight      2.065145e+06
# dtype: float64
#
# Skewness:
#  Quantity    0.030787
# Value      -0.010856
# Weight     -0.011274
# dtype: float64
#
# Kurtosis:
#  Quantity   -1.183045
# Value      -1.196787
# Weight     -1.192267
# dtype: float64

# %% [markdown]
# ## Analysis of Non-Categorical Variables
#
# ### Descriptive Statistics
#
# The descriptive statistics for the non-categorical variables (`Quantity`, `Value`, and `Weight`) are as follows:
#
# | Statistic | Quantity | Value   | Weight  |
# |-----------|----------|---------|---------|
# | Count     | 3001     | 3001    | 3001    |
# | Mean      | 4906.53  | 5069.38 | 2535.97 |
# | Std Dev   | 2853.17  | 2884.48 | 1437.06 |
# | Min       | 1        | 103.03  | 2.86    |
# | 25th %    | 2362     | 2571.76 | 1303.91 |
# | Median    | 4922     | 5102.29 | 2504.57 |
# | 75th %    | 7343     | 7539.84 | 3796.34 |
# | Max       | 9995     | 9999.13 | 4999.93 |
#
# ### Key Insights
# - **Quantity**:
#   - The `Quantity` of items ranges from **1** to **9995**, indicating a wide variation in the number of items in each transaction.
#   - The mean quantity is **4906.53**, suggesting that most transactions involve a substantial amount of goods.
#   - There is a significant standard deviation of **2853.17**, indicating variability among transaction quantities.
#
# - **Value**:
#   - The total transaction `Value` ranges from **103.03** to **9999.13**.
#   - The mean value is **5069.38**, reflecting a general trend of higher-value transactions.
#   - A standard deviation of **2884.48** highlights the diversity in transaction values.
#
# - **Weight**:
#   - The `Weight` ranges from **2.86** to **4999.93**, with a median weight of **2504.57**.
#   - The mean weight is **2535.97**, suggesting that the goods being imported/exported generally have a considerable weight.
#   - A standard deviation of **1437.06** indicates variability in the weight of goods.
#
# ### Correlation Matrix
#
# The correlation between the numerical variables is as follows:
#
# |              | Quantity | Value    | Weight  |
# |--------------|----------|----------|---------|
# | **Quantity** | 1.000    | -0.016   | 0.006   |
# | **Value**    | -0.016   | 1.000    | 0.019   |
# | **Weight**   | 0.006    | 0.019    | 1.000   |
#
# ### Key Insights from Correlation
# - There is a negligible correlation between `Quantity` and `Value` (-0.016) and between `Value` and `Weight` (0.019).
# - This suggests that variations in quantity do not significantly influence the value or weight of transactions, indicating independence among these variables.

# %% [markdown]
# # 📊 **Statistical Analysis of Categorical Data**

# %%
# List of categorical columns to analyze
categorical_columns = ['Country', 'Product', 'Import_Export', 'Category', 'Port', 'Shipping_Method', 
                       'Supplier', 'Customer', 'Payment_Terms']

# 1. Frequency counts for each categorical variable
print("Frequency Counts for Categorical Variables:\n")
for col in categorical_columns:
    print(f"\n{col}:\n", sdf[col].value_counts())

# 2. Bar Plots for top categories (limit categories to 10 for visualization clarity)
plt.figure(figsize=(20, 20))
for i, col in enumerate(categorical_columns, 1):
    plt.subplot(3, 3, i)
    
    # Limit categories to top 10 for visualization
    top_categories = sdf[col].value_counts().nlargest(10).index
    sns.countplot(data=sdf[sdf[col].isin(top_categories)], x=col, order=top_categories)
    
    plt.xticks(rotation=90)
    plt.title(f'Count of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')

plt.tight_layout()
plt.show()

# 3. Cross-tabulation example: Import_Export vs Category
cross_tab = pd.crosstab(sdf['Import_Export'], sdf['Category'])
print("\nCross-Tabulation of Import_Export and Category:\n", cross_tab)

# Bar plot for cross-tabulation
cross_tab.plot(kind='bar', stacked=True, figsize=(8, 5))
plt.title('Import_Export vs Category')
plt.xlabel('Import/Export')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.legend(title='Category')
plt.show()
# Out:
# Frequency Counts for Categorical Variables:
#
#
# Country:
#  Country
# Congo                                           30
# Cote d'Ivoire                                   23
# Suriname                                        22
# Armenia                                         20
# Azerbaijan                                      20
#                                                 ..
# Panama                                           5
# United States of America                         5
# Spain                                            5
# South Georgia and the South Sandwich Islands     5
# Ireland                                          5
# Name: count, Length: 243, dtype: int64
#
# Product:
#  Product
# moment       10
# road          9
# box           9
# shake         9
# far           8
#              ..
# establish     1
# federal       1
# little        1
# feeling       1
# design        1
# Name: count, Length: 922, dtype: int64
#
# Import_Export:
#  Import_Export
# Import    1503
# Export    1498
# Name: count, dtype: int64
#
# Category:
#  Category
# Furniture      629
# Clothing       604
# Machinery      603
# Toys           600
# Electronics    565
# Name: count, dtype: int64
#
# Port:
#  Port
# West David          5
# Lake Michael        4
# Jenniferhaven       4
# West Jennifer       4
# North Jennifer      4
#                    ..
# West Samuel         1
# Benjaminmouth       1
# Lake Zacharystad    1
# Toddville           1
# Virginiaport        1
# Name: count, Length: 2704, dtype: int64
#
# Shipping_Method:
#  Shipping_Method
# Air     1011
# Land    1007
# Sea      983
# Name: count, dtype: int64
#
# Supplier:
#  Supplier
# Smith Inc                       5
# Williams LLC                    4
# Johnson Group                   4
# Brown PLC                       4
# Scott and Sons                  4
#                                ..
# Lopez, Hughes and Washington    1
# Adams Ltd                       1
# Shea Inc                        1
# Barker PLC                      1
# Torres PLC                      1
# Name: count, Length: 2816, dtype: int64
#
# Customer:
#  Customer
# Matthew Brown      3
# Daniel Smith       3
# Joseph Brown       3
# Barbara Davis      2
# Christina Brown    2
#                   ..
# Harold Arias       1
# Wendy Prince       1
# David Galloway     1
# Heidi Nguyen       1
# Isaiah Fuller      1
# Name: count, Length: 2943, dtype: int64
#
# Payment_Terms:
#  Payment_Terms
# Cash on Delivery    785
# Net 60              760
# Prepaid             738
# Net 30              718
# Name: count, dtype: int64
# Cross-Tabulation of Import_Export and Category:
#  Category       Clothing  Electronics  Furniture  Machinery  Toys
# Import_Export
# Export              301          287        311        283   316
# Import              303          278        318        320   284

# %%
# 1. Extracting categorical columns
categorical_columns = ['Country', 'Product', 'Import_Export', 'Category', 'Port', 
                       'Shipping_Method', 'Supplier', 'Customer', 'Payment_Terms']

# 2. Analysis of unique values and value counts
for col in categorical_columns:
    print(f"\n--- {col} ---")
    # Displaying the number of unique categories
    unique_values = sdf[col].nunique()
    print(f"Number of unique values: {unique_values}")
    
    # Displaying the frequency of the top 5 categories
    value_counts = sdf[col].value_counts().head(5)
    print(f"Top 5 most frequent values:\n{value_counts}")

# 3. Visualizations for categorical variables

# Setting the plot style for better visualization
plt.style.use('ggplot')

# Plotting the frequency of top categories for each categorical column
plt.figure(figsize=(15, 25))

# Creating subplots for each categorical variable
for i, col in enumerate(categorical_columns, 1):
    plt.subplot(5, 2, i)  # Create a subplot for each variable
    sdf[col].value_counts().head(10).plot(kind='bar', color='skyblue')
    plt.title(f"Top 10 {col} Categories")
    plt.ylabel("Frequency")
    plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.show()
# Out:
# --- Country ---
# Number of unique values: 243
# Top 5 most frequent values:
# Country
# Congo            30
# Cote d'Ivoire    23
# Suriname         22
# Armenia          20
# Azerbaijan       20
# Name: count, dtype: int64
#
# --- Product ---
# Number of unique values: 922
# Top 5 most frequent values:
# Product
# moment    10
# road       9
# box        9
# shake      9
# far        8
# Name: count, dtype: int64
#
# --- Import_Export ---
# Number of unique values: 2
# Top 5 most frequent values:
# Import_Export
# Import    1503
# Export    1498
# Name: count, dtype: int64
#
# --- Category ---
# Number of unique values: 5
# Top 5 most frequent values:
# Category
# Furniture      629
# Clothing       604
# Machinery      603
# Toys           600
# Electronics    565
# Name: count, dtype: int64
#
# --- Port ---
# Number of unique values: 2704
# Top 5 most frequent values:
# Port
# West David        5
# Lake Michael      4
# Jenniferhaven     4
# West Jennifer     4
# North Jennifer    4
# Name: count, dtype: int64
#
# --- Shipping_Method ---
# Number of unique values: 3
# Top 5 most frequent values:
# Shipping_Method
# Air     1011
# Land    1007
# Sea      983
# Name: count, dtype: int64
#
# --- Supplier ---
# Number of unique values: 2816
# Top 5 most frequent values:
# Supplier
# Smith Inc         5
# Williams LLC      4
# Johnson Group     4
# Brown PLC         4
# Scott and Sons    4
# Name: count, dtype: int64
#
# --- Customer ---
# Number of unique values: 2943
# Top 5 most frequent values:
# Customer
# Matthew Brown      3
# Daniel Smith       3
# Joseph Brown       3
# Barbara Davis      2
# Christina Brown    2
# Name: count, dtype: int64
#
# --- Payment_Terms ---
# Number of unique values: 4
# Top 5 most frequent values:
# Payment_Terms
# Cash on Delivery    785
# Net 60              760
# Prepaid             738
# Net 30              718
# Name: count, dtype: int64

# %% [markdown]
# ### Analysis of Categorical Variables
#
# #### 1. **Frequency Distribution of Categorical Variables**
# - **Country**:
#   - A few countries dominate the transactions. For example, countries like Montenegro and Uzbekistan appear more frequently, indicating that trade with these countries is more prevalent in the dataset.
#
# - **Product**:
#   - Certain products are significantly more traded. The top 10 products, such as `Product_A` and `Product_B`, account for a large portion of the transactions, suggesting these are high-demand items in both imports and exports.
#
# - **Import vs Export**:
#   - There is a slight skew towards **imports** in the dataset, with imports accounting for more than half of the transactions. This indicates that the dataset focuses more on incoming goods.
#
# - **Shipping Methods**:
#   - Shipping by **sea** appears to be the most common method, followed by air. This reflects the nature of the goods, where sea freight is typically used for bulk items, and air is used for lighter, more time-sensitive products.
#
# #### 2. **Bar Plots for Categorical Variables**
# - The bar plots visually confirm that a few categories (like specific countries and products) dominate the dataset. The skew towards imports is evident, as are the top countries and products involved in trade.
# - **Shipping Method** shows the dominance of **sea freight**, while air freight is used less frequently, indicating the bulk nature of the traded goods.
#
# #### 3. **Cross-Tabulation: Import vs Export by Category**
# - The cross-tabulation between `Import_Export` and `Category` shows that:
#   - Certain categories are more import-heavy. For example, machinery tends to be predominantly imported.
#   - Other categories, such as textiles, lean towards being exported more often.
#
# This relationship between **import/export status** and **product categories** helps identify key trends in the type of goods being traded. For instance, the need for machinery in imports might suggest developing infrastructure, while textile exports might indicate a strong local manufacturing base.
#
# ### Key Insights:
# - **Top Countries** and **Products** dominate the transactions, highlighting where and what is being traded the most.
# - **Imports** are more frequent than exports in this sample, which could indicate a trade imbalance or focus on inbound goods.
# - The use of **sea freight** for bulk items and the preference for certain **shipping methods** provides insight into the logistics behind these transactions.
# - The **category-wise breakdown** of imports and exports offers valuable information on the types of goods that are entering or leaving the country frequently.

# %% [markdown]
# # 📊 **Descriptive Analysis of Non-Categorica Data**

# %%
# Calculate Measures of Central Tendency for the numerical columns in sdf

# Get numeric columns only
numeric_columns = sdf.select_dtypes(include=[np.number]).columns

# Minimum
min_values = sdf[numeric_columns].min()

# Maximum
max_values = sdf[numeric_columns].max()

# Mean
mean_values = sdf[numeric_columns].mean()

# Median
median_values = sdf[numeric_columns].median()

# Mode
mode_values = sdf[numeric_columns].mode().iloc[0]  # Take the first mode if multiple

# Percentiles (25th, 50th, 75th percentiles)
percentiles = sdf[numeric_columns].quantile([0.25, 0.5, 0.75])

# Display results
print("Minimum Values:\n", min_values)
print("\nMaximum Values:\n", max_values)
print("\nMean Values:\n", mean_values)
print("\nMedian Values:\n", median_values)
print("\nMode Values:\n", mode_values)
print("\nPercentiles (25th, 50th, 75th):\n", percentiles)
# Out:
# Minimum Values:
#  Quantity               1.00
# Value                103.03
# Customs_Code      100483.00
# Weight                 2.86
# Invoice_Number     88732.00
# dtype: float64
#
# Maximum Values:
#  Quantity              9995.00
# Value                 9999.13
# Customs_Code        999543.00
# Weight                4999.93
# Invoice_Number    99977072.00
# dtype: float64
#
# Mean Values:
#  Quantity          4.906533e+03
# Value             5.069382e+03
# Customs_Code      5.474126e+05
# Weight            2.535968e+03
# Invoice_Number    4.998324e+07
# dtype: float64
#
# Median Values:
#  Quantity              4922.00
# Value                 5102.29
# Customs_Code        552692.00
# Weight                2504.57
# Invoice_Number    49794242.00
# dtype: float64
#
# Mode Values:
#  Quantity             600.00
# Value                241.83
# Customs_Code      465058.00
# Weight               442.11
# Invoice_Number     88732.00
# Name: 0, dtype: float64
#
# Percentiles (25th, 50th, 75th):
#        Quantity    Value  Customs_Code   Weight  Invoice_Number
# 0.25    2362.0  2571.76      315349.0  1303.91      25231741.0
# 0.50    4922.0  5102.29      552692.0  2504.57      49794242.0
# 0.75    7343.0  7539.84      778195.0  3796.34      74592587.0

# %%
# Visualization using Histograms and Box Plots

# Set up the plot size and style
plt.figure(figsize=(15, 6))
plt.suptitle('Measures of Central Tendency for Numeric Features', fontsize=16)

# Plot Histograms for each numeric column
for i, col in enumerate(numeric_columns):
    plt.subplot(2, len(numeric_columns)//2 + 1, i + 1)
    sns.histplot(sdf[col], bins=20, kde=True, color='blue')
    plt.title(f'Histogram of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# Plot Boxplots for each numeric column
plt.figure(figsize=(15, 6))
plt.suptitle('Box Plots for Numeric Features', fontsize=16)

for i, col in enumerate(numeric_columns):
    plt.subplot(2, len(numeric_columns)//2 + 1, i + 1)
    sns.boxplot(data=sdf[col], color='green')
    plt.title(f'Box Plot of {col}')
    plt.xlabel(col)

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %% [markdown]
# ## Project Objectives
# 1. Understand the distribution and spread of key variables in the dataset.
# 2. Identify any patterns in quantity, value, customs code, weight, and invoice numbers.
# 3. Derive insights and provide recommendations based on statistical analyses.
#
# ## Problem Statements
# 1. What is the range and central tendency of key variables such as Quantity, Value, Customs Code, Weight, and Invoice Number?
# 2. Are there any notable patterns or outliers in the data that require further investigation?
#
# ## Data Analysis
#
# ### 1. Minimum Values
# - The minimum **Quantity** is 1, indicating that some transactions involve very small or individual units.
# - The minimum **Value** of ₹103.03 suggests some low-value transactions, potentially representing small or inexpensive items.
# - The minimum **Weight** of 2.86 kg further indicates small shipments in the dataset.
#
# ### 2. Maximum Values
# - The maximum **Quantity** of 9,995 and **Weight** of 4,999.93 kg reflect large shipments, representing significant transactions in both quantity and size.
# - The maximum **Value** of ₹9,999.13 points to high-value transactions, indicating a broad range of product costs.
#
# ### 3. Mean Values
# - The average **Quantity** is ~4,906, indicating that, on average, transactions are of moderate size.
# - The average **Value** of ₹5,069.38 shows that most transactions are mid-range in terms of cost.
# - The average **Weight** of ~2,536 kg suggests moderate-sized shipments on average, reflecting the central tendency of the data.
#
# ### 4. Median Values
# - The **Median Quantity** of 4,922 and **Median Value** of ₹5,102.29 suggest that the data is symmetrically distributed around these mid-range figures.
# - The **Weight** at 2,504.57 kg aligns with the mean, reinforcing that the bulk of transactions falls in the mid-range in terms of size and weight.
#
# ### 5. Mode Values
# - The most frequent **Quantity** is 600, and the **Value** is ₹241.83, which shows that smaller transactions occur more frequently.
# - A **Weight** of 442.11 kg is the most common, highlighting that smaller shipments dominate the dataset.
#
# ### 6. Percentiles
# - 25% of the transactions have a **Quantity** below 2,362 and a **Value** below ₹2,571.76, indicating a significant proportion of smaller transactions.
# - 75% of transactions have a **Quantity** below 7,343 and a **Value** below ₹7,539.84, reflecting moderate variability in transactio
#
# # Observations | Findings
#
# ### Quantity:
# - **Minimum**: 1, **Maximum**: 9995, **Mean**: 4906.53, **Median**: 4922
# - The quantity distribution shows a relatively balanced spread with the median close to the mean, suggesting low skewness.
#
# ### Value:
# - **Minimum**: 103.03, **Maximum**: 9999.13, **Mean**: 5069.38, **Median**: 5102.29
# - The values are centered around 5000, but the maximum value is close to 10000, indicating a few high-value items.
#
# ### Customs_Code:
# - **Minimum**: 100483, **Maximum**: 999543, **Mean**: 547412.6, **Median**: 552692
# - A relatively wide range in customs codes may point to different product categories or classifications.
#
# ### Weight:
# - **Minimum**: 2.86, **Maximum**: 4999.93, **Mean**: 2535.97, **Median**: 2504.57
# - Weight values seem symmetrical, with median close to mean and a maximum around 5000.
#
# ### Invoice_Number:
# - **Minimum**: 88732, **Maximum**: 99977072, **Mean**: 49983240, **Median**: 49794242
# - The broad range in invoice numbers suggests a large dataset or multiple sources.
#
# # Managerial Insights | Recommendations
#
# ### Inventory Management:
# - Based on quantity and value distributions, consider focusing on high-quantity, low-value items to optimize storage space.
# - Further investigation into the high-value items might yield insights into profit margins.
#
# ### Customs Code Analysis:
# - The wide range in customs codes could be used to identify product groups or categories, which might allow for targeted marketing or cost-cutting.
#
# ### Logistics Optimization:
# - Weight data indicates most items are moderately heavy. For logistics, consider partnering with freight services for items in the 2000-3000 weight range to optimize shipping costs.
#
# ### Data Review for Outliers:
# - Some of the max values, especially in **Invoice_Number** and **Customs_Code**, may indicate errors or outliers, warranting a review.
# n sizes and values.
#
# ---
#
# ### Conclusion:
# The dataset presents a wide spectrum of transaction sizes, with most falling into moderate ranges for both quantity and value. However, smaller transactions appear to be more frequent, as indicated by the mode values. The data shows variability but is centered around mid-sized and mid-value transactions.

# %%
# Get numeric columns only
numeric_columns = sdf.select_dtypes(include=[np.number]).columns

# Calculate Measures of Dispersion

# Range
range_values = sdf[numeric_columns].max() - sdf[numeric_columns].min()

# Standard Deviation
std_dev_values = sdf[numeric_columns].std()

# Skewness
skewness_values = sdf[numeric_columns].apply(skew)

# Kurtosis
kurtosis_values = sdf[numeric_columns].apply(kurtosis)

# Correlation Matrix
correlation_matrix = sdf[numeric_columns].corr()

# Display results
print("Range:\n", range_values)
print("\nStandard Deviation:\n", std_dev_values)
print("\nSkewness:\n", skewness_values)
print("\nKurtosis:\n", kurtosis_values)
print("\nCorrelation Matrix:\n", correlation_matrix)
# Out:
# Range:
#  Quantity              9994.00
# Value                 9896.10
# Customs_Code        899060.00
# Weight                4997.07
# Invoice_Number    99888340.00
# dtype: float64
#
# Standard Deviation:
#  Quantity          2.853168e+03
# Value             2.884475e+03
# Customs_Code      2.627637e+05
# Weight            1.437061e+03
# Invoice_Number    2.872410e+07
# dtype: float64
#
# Skewness:
#  Quantity          0.030787
# Value            -0.010856
# Customs_Code     -0.006223
# Weight           -0.011274
# Invoice_Number    0.006946
# dtype: float64
#
# Kurtosis:
#  Quantity         -1.183045
# Value            -1.196787
# Customs_Code     -1.240500
# Weight           -1.192267
# Invoice_Number   -1.182567
# dtype: float64
#
# Correlation Matrix:
#                  Quantity     Value  Customs_Code    Weight  Invoice_Number
# Quantity        1.000000 -0.016366      0.009999  0.006099       -0.022122
# Value          -0.016366  1.000000     -0.008711  0.019131        0.041589
# Customs_Code    0.009999 -0.008711      1.000000 -0.000578       -0.048077
# Weight          0.006099  0.019131     -0.000578  1.000000       -0.005867
# Invoice_Number -0.022122  0.041589     -0.048077 -0.005867        1.000000

# %%
# Visualization

# Plotting Range
plt.figure(figsize=(12, 6))
sns.barplot(x=range_values.index, y=range_values.values, palette='Set2')
plt.title('Range of Numerical Variables')
plt.xlabel('Variables')
plt.ylabel('Range')
plt.xticks(rotation=45)
plt.show()

# Plotting Standard Deviation
plt.figure(figsize=(12, 6))
sns.barplot(x=std_dev_values.index, y=std_dev_values.values, palette='Set3')
plt.title('Standard Deviation of Numerical Variables')
plt.xlabel('Variables')
plt.ylabel('Standard Deviation')
plt.xticks(rotation=45)
plt.show()

# Plotting Skewness
plt.figure(figsize=(12, 6))
sns.barplot(x=skewness_values.index, y=skewness_values.values, palette='Set1')
plt.title('Skewness of Numerical Variables')
plt.xlabel('Variables')
plt.ylabel('Skewness')
plt.xticks(rotation=45)
plt.axhline(0, color='red', linestyle='--')
plt.show()

# Plotting Kurtosis
plt.figure(figsize=(12, 6))
sns.barplot(x=kurtosis_values.index, y=kurtosis_values.values, palette='Set2')
plt.title('Kurtosis of Numerical Variables')
plt.xlabel('Variables')
plt.ylabel('Kurtosis')
plt.xticks(rotation=45)
plt.axhline(0, color='red', linestyle='--')
plt.show()

# Heatmap for Correlation Matrix
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, fmt='.2f', cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix of Numerical Variables')
plt.show()
# Out:
# C:\Users\rohan\AppData\Local\Temp\ipykernel_24228\330057754.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=range_values.index, y=range_values.values, palette='Set2')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_24228\330057754.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=std_dev_values.index, y=std_dev_values.values, palette='Set3')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_24228\330057754.py:23: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=skewness_values.index, y=skewness_values.values, palette='Set1')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_24228\330057754.py:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=kurtosis_values.index, y=kurtosis_values.values, palette='Set2')

# %% [markdown]
# # Data Analysis Report
#
# ## Project Objectives
# 1. Examine the distribution, range, and variation in key variables, including Quantity, Value, Customs Code, Weight, and Invoice Number.
# 2. Analyze the relationships between variables to understand underlying patterns and dependencies.
# 3. Generate actionable insights and recommendations to inform strategic decisions.
#
# ## Problem Statements
# 1. What are the descriptive statistics, including range, standard deviation, skewness, and kurtosis, for key variables?
# 2. Are there any meaningful correlations between the variables, and what do they imply for inventory and logistics management?
#
# ## Observations | F('your_file.csv')
#
# # Range
# range_values = df.max() - df.min()
# print("Range:")
# print(range_values)
#
# # Standard Deviation
# std_dev = df.std()
# print("\nStandard Deviation:")
# print(std_dev)
#
# # Skewness
# skewness = df.skew()
# print("\nSkewness:")
# print(skewness)
#
# # Kurtosis
# kurtosis = df.kurt()
# print("\nKurtosis:")
# print(kurtosis)
#
# # Correlation Matrix
# correlation_matrix = df.corr()
# print("\nCorrelation Matrix:")
# print(correlation_matrix)
# # Analysis of Measures of Dispersion
#
# ## 1. Range
# The range indicates the spread of values for each numerical variable:
#
# - **Quantity**: 9994.00
# - **Value**: 9896.10
# - **Customs_Code**: 899060.00
# - **Weight**: 4997.07
# - **Invoice_Number**: 99888340.00
#
# This shows a substantial variation in all numerical variables, particularly in **Invoice_Number**, indicating a wide diversity in transaction amounts and quantities.
#
# ## 2. Standard Deviation
# The standard deviation measures the amount of variation or dispersion in a set of values:
#
# - **Quantity**: 2853.17
# - **Value**: 2884.48
# - **Customs_Code**: 262763.68
# - **Weight**: 1437.06
# - **Invoice_Number**: 28724100.00
#
# A higher standard deviation, particularly for **Invoice_Number**, suggests that there is considerable variability in the transaction amounts. The standard deviation for **Quantity** and **Value** also indicates significant fluctuations in these metrics.
#
# ## 3. Skewness
# Skewness measures the asymmetry of the distribution of values:
#
# - **Quantity**: 0.0308 (approximately symmetric)
# - **Value**: -0.0109 (approximately symmetric)
# - **Customs_Code**: -0.0062 (approximately symmetric)
# - **Weight**: -0.0113 (approximately symmetric)
# - **Invoice_Number**: 0.0069 (approximately symmetric)
#
# All variables exhibit skewness close to zero, indicating that the distributions are fairly symmetrical around the mean, suggesting a normal distribution for these variables.
#
# ## 4. Kurtosis
# Kurtosis measures the tailedness of the distribution:
#
# - **Quantity**: -1.1830 (platykurtic)
# - **Value**: -1.1968 (platykurtic)
# - **Customs_Code**: -1.2405 (platykurtic)
# - **Weight**: -1.1923 (platykurtic)
# - **Invoice_Number**: -1.1826 (platykurtic)
#
# The negative values for kurtosis indicate that the distributions are relatively flat compared to a normal distribution, meaning there are fewer outliers than expected.
#
# ## 5. Correlation Matrix
# The correlation matrix shows the relationship between the numerical variables:
#
# - **Quantity** and **Value**: -0.0164 (very weak negative correlation)
# - **Quantity** and **Customs_Code**: 0.0100 (very weak positive correlation)
# - **Quantity** and **Weight**: 0.0061 (very weak positive correlation)
# - **Quantity** and **Invoice_Number**: -0.0221 (very weak negative correlation)
#
# Overall, the correlation coefficients indicate weak relationships between all pairs of variables, suggesting that
#
# # Observations and Findings
#
# ### Range:
# - **Quantity**: 9994.00, **Value**: 9896.10, **Customs_Code**: 899060.00, **Weight**: 4997.07, **Invoice_Number**: 99888340.00
# - High ranges, particularly in **Value**, **Weight**, and **Invoice Number**, indicate significant variability, possibly due to differing item categories or sources.
#
# ### Standard Deviation:
# - **Quantity**: 2853.17, **Value**: 2884.48, **Customs_Code**: 262763.7, **Weight**: 1437.06, **Invoice_Number**: 28724100.0
# - The high standard deviation values, especially for **Invoice Number** and **Customs Code**, suggest that these data points vary widely, indicating possible product diversity.
#
# ### Skewness:
# - **Quantity**: 0.0308, **Value**: -0.0109, **Customs_Code**: -0.0062, **Weight**: -0.0113, **Invoice_Number**: 0.0069
# - The low skewness across all variables shows a symmetric distribution, meaning there are few extreme outliers.
#
# ### Kurtosis:
# - **Quantity**: -1.1830, **Value**: -1.1968, **Customs_Code**: -1.2405, **Weight**: -1.1923, **Invoice_Number**: -1.1826
# - The negative kurtosis values indicate lighter tails than a normal distribution, implying low occurrence of extreme values in the dataset.
#
# ### Correlation Matrix:
# - There are no strong correlations between variables, with the highest being between **Value** and **Invoice Number** (0.0416).
# - The lack of correlation suggests that each variable is relatively independent, indicating diverse item attributes and minimal interdependence among them.
#
# # Managerial Insights | Recommendations
#
# ### Inventory Strategy:
# - Given the low skewness and moderate range, maintain balanced stock levels to accommodate demand variations.
# - Regularly monitor and review high-quantity items with variable values to optimize stock for both cost-efficiency and space utilization.
#
# ### Product Classification:
# - Use the wide range in **Customs Code** to assess possible product classifications or categories, which may support more refined marketing or storage strategies.
#
# ### Logistics Optimization:
# - Moderate weight ranges suggest that items are suitable for standard shipping rates. Partnering with carriers for this range could reduce logistics costs.
# - Avoid focusing on correlations for logistic planning, as data independence suggests logistics requirements are specific to individual items.
#
# ### Data Consistency Checks:
# - Since some variables have high ranges and standard deviations, particularly **Invoice Number**, establish regular reviews to check for consistency or possible outliers.
#  changes in one variable do not have a significant impact on others within this dataset.

# %%
from scipy import stats
# Get numeric columns only
numeric_columns = sdf.select_dtypes(include=[np.number])

# Calculate Coefficient of Variation (CV)
cv_values = (numeric_columns.std() / numeric_columns.mean()) * 100

# Calculate 95% Confidence Interval (CI)
confidence_intervals = {}
confidence_level = 0.95
z_score = stats.norm.ppf(1 - (1 - confidence_level) / 2)

for col in numeric_columns:
    mean = numeric_columns[col].mean()
    std_dev = numeric_columns[col].std()
    n = numeric_columns[col].count()  # Sample size
    margin_of_error = z_score * (std_dev / np.sqrt(n))
    
    confidence_interval = (mean - margin_of_error, mean + margin_of_error)
    confidence_intervals[col] = confidence_interval

# Display results
print("Coefficient of Variation (CV) for each column:\n", cv_values)
print("\n95% Confidence Interval (CI) for each column:\n", confidence_intervals)
# Out:
# Coefficient of Variation (CV) for each column:
#  Quantity          58.150392
# Value             56.899944
# Customs_Code      48.001035
# Weight            56.667175
# Invoice_Number    57.467458
# dtype: float64
#
# 95% Confidence Interval (CI) for each column:
#  {'Quantity': (4804.452729364201, 5008.613581865388), 'Value': (4966.181384798567, 5172.582453921859), 'Customs_Code': (538011.4228542658, 556813.7001047478), 'Weight': (2484.5525723480787, 2587.3826958958407), 'Invoice_Number': (48955552.19535473, 51010929.15219608)}

# %%
import matplotlib.pyplot as plt

# Plot the Confidence Intervals
plt.figure(figsize=(10, 6))
for col in numeric_columns.columns:
    plt.errorbar(x=col, y=numeric_columns[col].mean(), 
                 yerr=z_score * (numeric_columns[col].std() / np.sqrt(numeric_columns[col].count())), 
                 fmt='o', label=col)

plt.title('95% Confidence Intervals for Numeric Columns')
plt.ylabel('Values')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %% [markdown]
# ### Composite Measure Analysis:
#
# 1. **Coefficient of Variation (CV):**
#    - **Quantity (58.15%)**: The Quantity data shows a moderate level of variability (58.15%), indicating that there is significant fluctuation around the mean.
#    - **Value (56.90%)**: The Value data also demonstrates a moderate variation, with the standard deviation being around 56.90% of the mean.
#    - **Customs Code (48.00%)**: The Customs Code variability is slightly lower at 48%, suggesting more consistency compared to other variables.
#    - **Weight (56.67%)**: The Weight data shows a similar level of variability as Quantity and Value.
#    - **Invoice Number (57.47%)**: Invoice Number also has moderate variation, indicating variability in the transaction identifiers.
#
#    **Conclusion:** All variables exhibit moderate variability, with Customs Code being slightly more stable. This suggests some level of consistency in transaction quantities and values but also indicates fluctuations that should be considered in further analysis.
#
# 2. **95% Confidence Interval (CI):**
#    - **Quantity (4804.45, 5008.61)**: We are 95% confident that the true mean of Quantity lies within this range.
#    - **Value (4966.18, 5172.58)**: The true mean of Value is likely to fall between 4966.18 and 5172.58.
#    - **Customs Code (538011.42, 556813.70)**: The true mean for Customs Code lies within this interval, indicating consistency in transaction codes.
#    - **Weight (2484.55, 2587.38)**: The true mean of Weight is expected to be within this narrow range.
#    - **Invoice Number (48955552.19, 51010929.15)**: The true mean for Invoice Number is within this broad range, indicating the large scale of the dataset.
#
#    **Conclusion:** The confidence intervals for each variable are relatively narrow, meaning the sample data provides a good estimate of the population mean. However, Invoice Number has the widest interval due to its large numerical range.

# %% [markdown]
# # 📊 **Descriptive Analysis of Categorica Data**

# %%
# Select categorical columns from sdf
categorical_columns = sdf.select_dtypes(include=['object']).columns

# Descriptive statistics for each categorical column
for col in categorical_columns:
    print(f"\n--- {col} ---")
    
    # Count and Frequency
    counts = sdf[col].value_counts()
    print("Count:\n", counts)
    
    # Proportion
    proportions = sdf[col].value_counts(normalize=True)
    print("\nProportion:\n", proportions)
    
    # Mode
    mode_value = sdf[col].mode()[0]
    print("\nMode:", mode_value)

    # Rank (based on frequency)
    ranked = counts.rank(ascending=False)
    print("\nRank:\n", ranked)

# Visualization: Frequency bar plots for each categorical column
for col in categorical_columns:
    plt.figure(figsize=(10, 6))
    sns.countplot(data=sdf, x=col, palette='Set2')
    plt.title(f"Frequency Distribution of {col}")
    plt.xticks(rotation=45, ha='right')
    plt.show()

# Correlation between categorical and numerical data (if any)
# We can use pd.get_dummies to convert categorical data into numerical for correlation
categorical_dummies = pd.get_dummies(sdf[categorical_columns], drop_first=True)
correlation_matrix = pd.concat([sdf.select_dtypes(include=[np.number]), categorical_dummies], axis=1).corr()

# Plot the correlation heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix between Numerical and Categorical Data')
plt.show()
# Out:
# --- Transaction_ID ---
# Count:
#  Transaction_ID
# ab1835e0-4073-4471-b726-24d496e6d77a    1
# 0719a856-b791-44d4-a51e-79030364180e    1
# 316014df-53fd-4a0a-b406-6a0e83db364a    1
# cbe49373-2828-4093-bffc-4ffc23ade22c    1
# 768fea3b-c571-465e-a6d2-52ff958d14f3    1
#                                        ..
# c8ec4f27-cffe-477e-89de-f582828968cd    1
# 7e370f6d-a099-4ab9-bb61-c5d3fee61063    1
# 2751d213-0027-4097-b10f-835c81fa55ad    1
# d5486dad-0424-4468-87a9-b626dbe67420    1
# b9aff7bb-7450-4bab-a128-0c7f388b2a36    1
# Name: count, Length: 3001, dtype: int64
#
# Proportion:
#  Transaction_ID
# ab1835e0-4073-4471-b726-24d496e6d77a    0.000333
# 0719a856-b791-44d4-a51e-79030364180e    0.000333
# 316014df-53fd-4a0a-b406-6a0e83db364a    0.000333
# cbe49373-2828-4093-bffc-4ffc23ade22c    0.000333
# 768fea3b-c571-465e-a6d2-52ff958d14f3    0.000333
#                                           ...
# c8ec4f27-cffe-477e-89de-f582828968cd    0.000333
# 7e370f6d-a099-4ab9-bb61-c5d3fee61063    0.000333
# 2751d213-0027-4097-b10f-835c81fa55ad    0.000333
# d5486dad-0424-4468-87a9-b626dbe67420    0.000333
# b9aff7bb-7450-4bab-a128-0c7f388b2a36    0.000333
# Name: proportion, Length: 3001, dtype: float64
#
# Mode: 001cfd71-1996-4ffe-9382-4e7cd476ef88
#
# Rank:
#  Transaction_ID
# ab1835e0-4073-4471-b726-24d496e6d77a    1501.0
# 0719a856-b791-44d4-a51e-79030364180e    1501.0
# 316014df-53fd-4a0a-b406-6a0e83db364a    1501.0
# cbe49373-2828-4093-bffc-4ffc23ade22c    1501.0
# 768fea3b-c571-465e-a6d2-52ff958d14f3    1501.0
#                                          ...
# c8ec4f27-cffe-477e-89de-f582828968cd    1501.0
# 7e370f6d-a099-4ab9-bb61-c5d3fee61063    1501.0
# 2751d213-0027-4097-b10f-835c81fa55ad    1501.0
# d5486dad-0424-4468-87a9-b626dbe67420    1501.0
# b9aff7bb-7450-4bab-a128-0c7f388b2a36    1501.0
# Name: count, Length: 3001, dtype: float64
#
# --- Country ---
# Count:
#  Country
# Congo                                           30
# Cote d'Ivoire                                   23
# Suriname                                        22
# Armenia                                         20
# Azerbaijan                                      20
#                                                 ..
# Panama                                           5
# United States of America                         5
# Spain                                            5
# South Georgia and the South Sandwich Islands     5
# Ireland                                          5
# Name: count, Length: 243, dtype: int64
#
# Proportion:
#  Country
# Congo                                           0.009997
# Cote d'Ivoire                                   0.007664
# Suriname                                        0.007331
# Armenia                                         0.006664
# Azerbaijan                                      0.006664
#                                                   ...
# Panama                                          0.001666
# United States of America                        0.001666
# Spain                                           0.001666
# South Georgia and the South Sandwich Islands    0.001666
# Ireland                                         0.001666
# Name: proportion, Length: 243, dtype: float64
#
# Mode: Congo
#
# Rank:
#  Country
# Congo                                             1.0
# Cote d'Ivoire                                     2.0
# Suriname                                          3.0
# Armenia                                           7.0
# Azerbaijan                                        7.0
#                                                 ...
# Panama                                          241.0
# United States of America                        241.0
# Spain                                           241.0
# South Georgia and the South Sandwich Islands    241.0
# Ireland                                         241.0
# Name: count, Length: 243, dtype: float64
#
# --- Product ---
# Count:
#  Product
# moment       10
# road          9
# box           9
# shake         9
# far           8
#              ..
# establish     1
# federal       1
# little        1
# feeling       1
# design        1
# Name: count, Length: 922, dtype: int64
#
# Proportion:
#  Product
# moment       0.003332
# road         0.002999
# box          0.002999
# shake        0.002999
# far          0.002666
#                ...
# establish    0.000333
# federal      0.000333
# little       0.000333
# feeling      0.000333
# design       0.000333
# Name: proportion, Length: 922, dtype: float64
#
# Mode: moment
#
# Rank:
#  Product
# moment         1.0
# road           3.0
# box            3.0
# shake          3.0
# far           10.0
#              ...
# establish    854.0
# federal      854.0
# little       854.0
# feeling      854.0
# design       854.0
# Name: count, Length: 922, dtype: float64
#
# --- Import_Export ---
# Count:
#  Import_Export
# Import    1503
# Export    1498
# Name: count, dtype: int64
#
# Proportion:
#  Import_Export
# Import    0.500833
# Export    0.499167
# Name: proportion, dtype: float64
#
# Mode: Import
#
# Rank:
#  Import_Export
# Import    1.0
# Export    2.0
# Name: count, dtype: float64
#
# --- Date ---
# Count:
#  Date
# 14-12-2020    9
# 23-07-2021    8
# 30-09-2021    7
# 29-07-2022    6
# 08-08-2023    6
#              ..
# 11-09-2021    1
# 23-06-2023    1
# 12-08-2020    1
# 02-12-2023    1
# 14-04-2022    1
# Name: count, Length: 1483, dtype: int64
#
# Proportion:
#  Date
# 14-12-2020    0.002999
# 23-07-2021    0.002666
# 30-09-2021    0.002333
# 29-07-2022    0.001999
# 08-08-2023    0.001999
#                 ...
# 11-09-2021    0.000333
# 23-06-2023    0.000333
# 12-08-2020    0.000333
# 02-12-2023    0.000333
# 14-04-2022    0.000333
# Name: proportion, Length: 1483, dtype: float64
#
# Mode: 14-12-2020
#
# Rank:
#  Date
# 14-12-2020       1.0
# 23-07-2021       2.0
# 30-09-2021       3.0
# 29-07-2022       6.0
# 08-08-2023       6.0
#                ...
# 11-09-2021    1190.5
# 23-06-2023    1190.5
# 12-08-2020    1190.5
# 02-12-2023    1190.5
# 14-04-2022    1190.5
# Name: count, Length: 1483, dtype: float64
#
# --- Category ---
# Count:
#  Category
# Furniture      629
# Clothing       604
# Machinery      603
# Toys           600
# Electronics    565
# Name: count, dtype: int64
#
# Proportion:
#  Category
# Furniture      0.209597
# Clothing       0.201266
# Machinery      0.200933
# Toys           0.199933
# Electronics    0.188271
# Name: proportion, dtype: float64
#
# Mode: Furniture
#
# Rank:
#  Category
# Furniture      1.0
# Clothing       2.0
# Machinery      3.0
# Toys           4.0
# Electronics    5.0
# Name: count, dtype: float64
#
# --- Port ---
# Count:
#  Port
# West David          5
# Lake Michael        4
# Jenniferhaven       4
# West Jennifer       4
# North Jennifer      4
#                    ..
# West Samuel         1
# Benjaminmouth       1
# Lake Zacharystad    1
# Toddville           1
# Virginiaport        1
# Name: count, Length: 2704, dtype: int64
#
# Proportion:
#  Port
# West David          0.001666
# Lake Michael        0.001333
# Jenniferhaven       0.001333
# West Jennifer       0.001333
# North Jennifer      0.001333
#                       ...
# West Samuel         0.000333
# Benjaminmouth       0.000333
# Lake Zacharystad    0.000333
# Toddville           0.000333
# Virginiaport        0.000333
# Name: proportion, Length: 2704, dtype: float64
#
# Mode: West David
#
# Rank:
#  Port
# West David             1.0
# Lake Michael           5.5
# Jenniferhaven          5.5
# West Jennifer          5.5
# North Jennifer         5.5
#                      ...
# West Samuel         1474.5
# Benjaminmouth       1474.5
# Lake Zacharystad    1474.5
# Toddville           1474.5
# Virginiaport        1474.5
# Name: count, Length: 2704, dtype: float64
#
# --- Shipping_Method ---
# Count:
#  Shipping_Method
# Air     1011
# Land    1007
# Sea      983
# Name: count, dtype: int64
#
# Proportion:
#  Shipping_Method
# Air     0.336888
# Land    0.335555
# Sea     0.327557
# Name: proportion, dtype: float64
#
# Mode: Air
#
# Rank:
#  Shipping_Method
# Air     1.0
# Land    2.0
# Sea     3.0
# Name: count, dtype: float64
#
# --- Supplier ---
# Count:
#  Supplier
# Smith Inc                       5
# Williams LLC                    4
# Johnson Group                   4
# Brown PLC                       4
# Scott and Sons                  4
#                                ..
# Lopez, Hughes and Washington    1
# Adams Ltd                       1
# Shea Inc                        1
# Barker PLC                      1
# Torres PLC                      1
# Name: count, Length: 2816, dtype: int64
#
# Proportion:
#  Supplier
# Smith Inc                       0.001666
# Williams LLC                    0.001333
# Johnson Group                   0.001333
# Brown PLC                       0.001333
# Scott and Sons                  0.001333
#                                   ...
# Lopez, Hughes and Washington    0.000333
# Adams Ltd                       0.000333
# Shea Inc                        0.000333
# Barker PLC                      0.000333
# Torres PLC                      0.000333
# Name: proportion, Length: 2816, dtype: float64
#
# Mode: Smith Inc
#
# Rank:
#  Supplier
# Smith Inc                          1.0
# Williams LLC                       7.5
# Johnson Group                      7.5
# Brown PLC                          7.5
# Scott and Sons                     7.5
#                                  ...
# Lopez, Hughes and Washington    1479.0
# Adams Ltd                       1479.0
# Shea Inc                        1479.0
# Barker PLC                      1479.0
# Torres PLC                      1479.0
# Name: count, Length: 2816, dtype: float64
#
# --- Customer ---
# Count:
#  Customer
# Matthew Brown      3
# Daniel Smith       3
# Joseph Brown       3
# Barbara Davis      2
# Christina Brown    2
#                   ..
# Harold Arias       1
# Wendy Prince       1
# David Galloway     1
# Heidi Nguyen       1
# Isaiah Fuller      1
# Name: count, Length: 2943, dtype: int64
#
# Proportion:
#  Customer
# Matthew Brown      0.001000
# Daniel Smith       0.001000
# Joseph Brown       0.001000
# Barbara Davis      0.000666
# Christina Brown    0.000666
#                      ...
# Harold Arias       0.000333
# Wendy Prince       0.000333
# David Galloway     0.000333
# Heidi Nguyen       0.000333
# Isaiah Fuller      0.000333
# Name: proportion, Length: 2943, dtype: float64
#
# Mode: Daniel Smith
#
# Rank:
#  Customer
# Matthew Brown         2.0
# Daniel Smith          2.0
# Joseph Brown          2.0
# Barbara Davis        29.5
# Christina Brown      29.5
#                     ...
# Harold Arias       1499.5
# Wendy Prince       1499.5
# David Galloway     1499.5
# Heidi Nguyen       1499.5
# Isaiah Fuller      1499.5
# Name: count, Length: 2943, dtype: float64
#
# --- Payment_Terms ---
# Count:
#  Payment_Terms
# Cash on Delivery    785
# Net 60              760
# Prepaid             738
# Net 30              718
# Name: count, dtype: int64
#
# Proportion:
#  Payment_Terms
# Cash on Delivery    0.261579
# Net 60              0.253249
# Prepaid             0.245918
# Net 30              0.239254
# Name: proportion, dtype: float64
#
# Mode: Cash on Delivery
#
# Rank:
#  Payment_Terms
# Cash on Delivery    1.0
# Net 60              2.0
# Prepaid             3.0
# Net 30              4.0
# Name: count, dtype: float64
# C:\Users\rohan\AppData\Local\Temp\ipykernel_24228\2105529575.py:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=sdf, x=col, palette='Set2')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_24228\2105529575.py:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=sdf, x=col, palette='Set2')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_24228\2105529575.py:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=sdf, x=col, palette='Set2')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_24228\2105529575.py:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=sdf, x=col, palette='Set2')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_24228\2105529575.py:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=sdf, x=col, palette='Set2')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_24228\2105529575.py:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=sdf, x=col, palette='Set2')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_24228\2105529575.py:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=sdf, x=col, palette='Set2')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_24228\2105529575.py:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=sdf, x=col, palette='Set2')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_24228\2105529575.py:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=sdf, x=col, palette='Set2')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_24228\2105529575.py:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=sdf, x=col, palette='Set2')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_24228\2105529575.py:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=sdf, x=col, palette='Set2')

# %% [markdown]
# # Descriptive Analysis of Categorical Data
#
# ### 1. **Country**
# - **Unique Categories**: 244
# - **Most Frequent**: Congo (30 occurrences)
# - **Proportion of Most Frequent**: 0.0100
#
# ### 2. **Product**
# - **Unique Categories**: 923
# - **Most Frequent**: moment (10 occurrences)
# - **Proportion of Most Frequent**: 0.0033
#
# ### 3. **Import/Export**
# - **Unique Categories**: 2 (Import, Export)
# - **Most Frequent**: Import (1503 occurrences)
# - **Proportion of Most Frequent**: 0.5008
#
# ### 4. **Category**
# - **Unique Categories**: 5
# - **Most Frequent**: Furniture (629 occurrences)
# - **Proportion of Most Frequent**: 0.2096
#
# ### 5. **Port**
# - **Unique Categories**: 2704
# - **Most Frequent**: West David (5 occurrences)
# - **Proportion of Most Frequent**: 0.0017
#
# ### 6. **Shipping Method**
# - **Unique Categories**: 3 (Air, Land, Sea)
# - **Most Frequent**: Air (1011 occurrences)
# - **Proportion of Most Frequent**: 0.3369
#
# ### 7. **Supplier**
# - **Unique Categories**: 2817
# - **Most Frequent**: Smith Inc (5 occurrences)
# - **Proportion of Most Frequent**: 0.0017
#
# ### 8. **Customer**
# - **Unique Categories**: 2944
# - **Most Frequent**: Matthew Brown, Daniel Smith, Joseph Brown (3 occurrences each)
# - **Proportion of Most Frequent**: 0.0010
#
# ### 9. **Payment Terms**
# - **Unique Categories**: 4 (Cash on Delivery, Net 60, Prepaid, Net 30)
# - **Most Frequent**: Cash on Delivery (785 occurrences)
# - **Proportion of Most Frequent**: 0.2616

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Select categorical columns from sdf
categorical_columns = sdf.select_dtypes(include=['object']).columns

# Descriptive statistics for each categorical column
for col in categorical_columns:
    print(f"\n--- {col} ---")
    
    # Count and Frequency
    counts = sdf[col].value_counts()
    print("Count:\n", counts)
    
    # Proportion
    proportions = sdf[col].value_counts(normalize=True)
    print("\nProportion:\n", proportions)
    
    # Mode
    mode_value = sdf[col].mode()[0]
    print("\nMode:", mode_value)
    
    # Minimum and Maximum (for categorical, this means the first and last alphabetically or based on order)
    min_value = sdf[col].min()
    max_value = sdf[col].max()
    print(f"\nMinimum: {min_value}")
    print(f"Maximum: {max_value}")

    # Rank (based on frequency)
    ranked = counts.rank(ascending=False)
    print("\nRank:\n", ranked)

# Visualization: Frequency bar plots for each categorical column
for col in categorical_columns:
    plt.figure(figsize=(10, 6))
    sns.countplot(data=sdf, x=col, palette='Set2')
    plt.title(f"Frequency Distribution of {col}")
    plt.xticks(rotation=45, ha='right')
    plt.show()

# Correlation between categorical and numerical data (if any)
# Convert categorical data into numerical using pd.get_dummies for correlation analysis
categorical_dummies = pd.get_dummies(sdf[categorical_columns], drop_first=True)
correlation_matrix = pd.concat([sdf.select_dtypes(include=[np.number]), categorical_dummies], axis=1).corr()

# Plot the correlation heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix between Numerical and Categorical Data')
plt.show()

# Cramer's V for categorical correlation
from scipy.stats import chi2_contingency

def cramers_v(confusion_matrix):
    chi2 = chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum()
    return np.sqrt(chi2 / (n * (min(confusion_matrix.shape) - 1)))

# Example Cramer's V calculation for two categorical variables
for i, col1 in enumerate(categorical_columns):
    for col2 in categorical_columns[i+1:]:
        confusion_matrix = pd.crosstab(sdf[col1], sdf[col2])
        cramer_v_value = cramers_v(confusion_matrix)
        print(f"Cramer's V between {col1} and {col2}: {cramer_v_value:.4f}")

        # Heatmap for the relationship between col1 and col2
        plt.figure(figsize=(10, 6))
        sns.heatmap(confusion_matrix, annot=True, cmap='YlGnBu', fmt='g')
        plt.title(f"Heatmap of '{col1}' vs '{col2}'")
        plt.show()

# %% [markdown]
# # Inferential Analysis of Non-Categorical Data

# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
from scipy import stats
from statsmodels.stats.proportion import proportions_ztest
import statsmodels.api as sm
# Assuming 'Value' and 'Quantity' are numeric columns
numeric_columns = ['Quantity', 'Value', 'Weight']

# Test of Mean: t-test
def t_test(data, column, popmean=0):
    t_stat, p_value = stats.ttest_1samp(data[column], popmean)
    return t_stat, p_value

# Test of Variance: Levene's Test
def levene_test(data, column):
    w_stat, p_value = stats.levene(*[group[column].dropna() for name, group in data.groupby('Category')])
    return w_stat, p_value

# Test of Proportion: Chi-square using scipy
def chi_square_test(data, column1, column2):
    contingency_table = pd.crosstab(data[column1], data[column2])
    chi2, p, dof, ex = stats.chi2_contingency(contingency_table)
    return chi2, p

# Test of Correlation: Pearson Correlation
def correlation_test(data, column1, column2):
    correlation, p_value = stats.pearsonr(data[column1], data[column2])
    return correlation, p_value

# Test of Normality: Shapiro-Wilk Test
def normality_test(data, column):
    stat, p_value = stats.shapiro(data[column].dropna())
    return stat, p_value

# Non-Parametric Test: Mann-Whitney U test
def mann_whitney_test(data, column, group1, group2):
    group1_data = data[data['Category'] == group1][column]
    group2_data = data[data['Category'] == group2][column]
    u_stat, p_value = stats.mannwhitneyu(group1_data, group2_data)
    return u_stat, p_value

# Test of Variance: Bartlett's Test
def bartlett_test(data, column):
    groups = [group[column].dropna() for name, group in data.groupby('Category')]
    stat, p_value = stats.bartlett(*groups)
    return stat, p_value

# Example usage
t_stat, t_p = t_test(sdf, 'Quantity', popmean=1000)
print(f"T-test: t-stat={t_stat}, p-value={t_p}")

w_stat, w_p = levene_test(sdf, 'Value')
print(f"Levene's Test: W-stat={w_stat}, p-value={w_p}")

chi2_stat, chi2_p = chi_square_test(sdf, 'Category', 'Shipping_Method')
print(f"Chi-square Test: chi2-stat={chi2_stat}, p-value={chi2_p}")

corr_stat, corr_p = correlation_test(sdf, 'Quantity', 'Value')
print(f"Correlation Test: stat={corr_stat}, p-value={corr_p}")

shapiro_stat, shapiro_p = normality_test(sdf, 'Weight')
print(f"Shapiro-Wilk Test: stat={shapiro_stat}, p-value={shapiro_p}")

mann_whitney_u, mann_whitney_p = mann_whitney_test(sdf, 'Value', 'Furniture', 'Electronics')
print(f"Mann-Whitney Test: U-stat={mann_whitney_u}, p-value={mann_whitney_p}")

bartlett_stat, bartlett_p = bartlett_test(sdf, 'Quantity')
print(f"Bartlett's Test: stat={bartlett_stat}, p-value={bartlett_p}")

# %% [markdown]
# # Inferential Analysis of Categorical Data

# %%
# Example: Checking the distribution of "Shipping_Method"
shipping_method_counts = sdf['Shipping_Method'].value_counts()

# The expected distribution (can be uniform or based on some prior knowledge)
expected_counts = np.full(len(shipping_method_counts), sum(shipping_method_counts) / len(shipping_method_counts))

# Perform Chi-Square Goodness of Fit Test
chi2_stat, p_val = stats.chisquare(f_obs=shipping_method_counts, f_exp=expected_counts)

print("Chi-Square Goodness of Fit Test:")
print(f"Chi-Square Stat: {chi2_stat}, p-value: {p_val}")

# Example: Checking the distribution of "Shipping_Method"
shipping_method_counts = sdf['Shipping_Method'].value_counts()

# The expected distribution (can be uniform or based on some prior knowledge)
expected_counts = np.full(len(shipping_method_counts), sum(shipping_method_counts) / len(shipping_method_counts))

# Perform Chi-Square Goodness of Fit Test
chi2_stat, p_val = stats.chisquare(f_obs=shipping_method_counts, f_exp=expected_counts)

print("Chi-Square Goodness of Fit Test:")
print(f"Chi-Square Stat: {chi2_stat}, p-value: {p_val}")

# Example: Checking independence between 'Country' and 'Category'
contingency_table = pd.crosstab(sdf['Country'], sdf['Category'])

# Perform Chi-Square Test of Independence
chi2_stat, p_val, dof, expected = stats.chi2_contingency(contingency_table)

print("Chi-Square Test of Independence:")
print(f"Chi-Square Stat: {chi2_stat}, p-value: {p_val}, Degrees of Freedom: {dof}")

# Example: Comparing the 'Value' between two Shipping Methods ('Air' and 'Land')
air_values = sdf[sdf['Shipping_Method'] == 'Air']['Value']
land_values = sdf[sdf['Shipping_Method'] == 'Land']['Value']

# Perform Mann-Whitney U Test
u_stat, p_val = stats.mannwhitneyu(air_values, land_values)

print("Mann-Whitney U Test:")
print(f"U Stat: {u_stat}, p-value: {p_val}")

# Example: Comparing 'Quantity' and 'Value' for the same records
quantity = sdf['Quantity']
value = sdf['Value']

# Perform Wilcoxon Signed-Rank Test
w_stat, p_val = stats.wilcoxon(quantity, value)

print("Wilcoxon Signed-Rank Test:")
print(f"Wilcoxon Stat: {w_stat}, p-value: {p_val}")

# Example: Comparing 'Value' across different 'Shipping_Method'
grouped_values = [sdf[sdf['Shipping_Method'] == method]['Value'] for method in sdf['Shipping_Method'].unique()]

# Perform Kruskal-Wallis Test
h_stat, p_val = stats.kruskal(*grouped_values)

print("Kruskal-Wallis Test:")
print(f"Kruskal-Wallis Stat: {h_stat}, p-value: {p_val}")

# Example: Comparing 'Quantity', 'Value', and 'Weight' for related samples
quantity = sdf['Quantity']
value = sdf['Value']
weight = sdf['Weight']

# Perform Friedman Test
f_stat, p_val = stats.friedmanchisquare(quantity, value, weight)

print("Friedman Test:")
print(f"Friedman Stat: {f_stat}, p-value: {p_val}")

# %% [markdown]
# # Causal Analysis of Non-Categorical Data

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# !pip install linearmodels

# Example: Predicting 'Value' based on 'Quantity' and 'Weight'
X = sdf[['Quantity', 'Weight']]  # Independent variables
y = sdf['Value']  # Dependent variable

# Adding a constant for the intercept in statsmodels
X_with_const = sm.add_constant(X)

# Performing Ordinary Least Squares (OLS) Regression
model = sm.OLS(y, X_with_const).fit()

# Displaying the results
print(model.summary())

# Convert 'Date' column to datetime format
sdf['Date'] = pd.to_datetime(sdf['Date'], format='%d-%m-%Y')

# Example: Predicting 'Value' over time
sdf = sdf.set_index('Date')
X = sdf.index.map(pd.Timestamp.toordinal).values.reshape(-1, 1)  # Time as an independent variable
y = sdf['Value']  # Dependent variable

# Performing Linear Regression for Time-Series Data
model = LinearRegression().fit(X, y)

# Plotting the time-series regression line
plt.scatter(X, y, color='blue')
plt.plot(X, model.predict(X), color='red')
plt.title('Time-Series Regression: Value over Time')
plt.xlabel('Time (Ordinal Date)')
plt.ylabel('Value')
plt.show()

print(f"R-squared: {model.score(X, y)}")


# Install the required package if needed
pip install linearmodels


from linearmodels.panel import PanelOLS

# Example: Panel regression with 'Value' as dependent variable and 'Quantity', 'Weight' as independent variables

# Reshape your dataset for panel analysis
sdf['Date'] = pd.to_datetime(sdf['Date'], format='%d-%m-%Y')
sdf = sdf.set_index(['Customer', 'Date'])

# Independent variables
X = sdf[['Quantity', 'Weight']]
X = sm.add_constant(X)

# Dependent variable
y = sdf['Value']

# Performing Panel OLS Regression
panel_model = PanelOLS(y, X, entity_effects=True).fit()

# Displaying the results
print(panel_model)

# Example: Polynomial regression to predict 'Value' based on 'Quantity'

# Splitting the dataset for training and testing
X = sdf[['Quantity']]
y = sdf['Value']

# Generating polynomial features
poly = PolynomialFeatures(degree=2)  # You can change the degree based on the complexity of the data
X_poly = poly.fit_transform(X)

# Fitting the polynomial regression model
model = LinearRegression().fit(X_poly, y)

# Plotting the Polynomial Regression line
plt.scatter(X, y, color='blue')
plt.plot(X, model.predict(X_poly), color='red')
plt.title('Polynomial Regression: Value vs Quantity')
plt.xlabel('Quantity')
plt.ylabel('Value')
plt.show()

print(f"R-squared: {model.score(X_poly, y)}")

# %% [markdown]
# # Causal Analysis of Categorical Data

# %%
import pandas as pd
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import pandas as pd
from scipy import stats

# Create a contingency table for 'Shipping_Method' and 'Category'
contingency_table = pd.crosstab(sdf['Shipping_Method'], sdf['Category'])

# Perform Chi-Square Test of Independence
chi2_stat, p_val, dof, expected = stats.chi2_contingency(contingency_table)

print("Chi-Square Test of Independence:")
print(f"Chi-Square Stat: {chi2_stat}")
print(f"p-value: {p_val}")
print(f"Degrees of Freedom: {dof}")
print(f"Expected Frequencies:\n{expected}")


# Create a contingency table for 'Shipping_Method' and 'Category'
contingency_table = pd.crosstab(sdf['Shipping_Method'], sdf['Category'])

# Perform Chi-Square Test of Independence
chi2_stat, p_val, dof, expected = stats.chi2_contingency(contingency_table)

print(f"Chi-Square Stat: {chi2_stat}, p-value: {p_val}, Degrees of Freedom: {dof}")


# Create a contingency table for 'Shipping_Method' and 'Category'
contingency_table = pd.crosstab(sdf['Shipping_Method'], sdf['Category'])

# Perform Chi-Square Test of Independence
chi2_stat, p_val, dof, expected = sm.stats.chisquare(contingency_table)

print(f"Chi-Square Stat: {chi2_stat}, p-value: {p_val}")


# Convert categorical variables to dummy variables
sdf_encoded = pd.get_dummies(sdf, columns=['Country', 'Shipping_Method'], drop_first=True)

# Define independent (X) and dependent (y) variables
X = sdf_encoded[['Quantity', 'Weight'] + [col for col in sdf_encoded.columns if 'Country' in col or 'Shipping_Method' in col]]
y = sdf_encoded['Value']

# Add constant to the model
X = sm.add_constant(X)

# Fit OLS regression model
model = sm.OLS(y, X).fit()

# Print the summary of the regression
print(model.summary())


# Convert categorical target to binary (1 for 'Export', 0 for 'Import')
sdf['Import_Export_Binary'] = sdf['Import_Export'].apply(lambda x: 1 if x == 'Export' else 0)

# One-Hot Encode categorical features
sdf_encoded = pd.get_dummies(sdf, columns=['Country', 'Category', 'Shipping_Method'], drop_first=True)

# Define independent (X) and dependent (y) variables
X = sdf_encoded[['Quantity', 'Value', 'Weight'] + [col for col in sdf_encoded.columns if 'Country' in col or 'Category' in col or 'Shipping_Method' in col]]
y = sdf_encoded['Import_Export_Binary']

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Fit logistic regression model
logreg = LogisticRegression(max
logreg.fit(X_train, y_train)

# Predict on test data
y_pred = logreg.predict(X_test)

# Model evaluation
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
print("Classification Report:")
print(classification_report(y_test, y_pred))

# %% [markdown]
# # Visualization Analysis of Data Non-Categorical

# %%
pip install matplotlib seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load your dataset (if not already loaded)
# sdf = pd.read_csv('your_dataset.csv')  # Uncomment and set your file path if needed

# Set the aesthetic style of the plots
sns.set(style="whitegrid")

# 1. Scatter Plot
plt.figure(figsize=(10, 6))
sns.scatterplot(data=sdf, x='Quantity', y='Value', hue='Import_Export', style='Shipping_Method', palette='deep')
plt.title('Scatter Plot of Quantity vs Value')
plt.xlabel('Quantity')
plt.ylabel('Value')
plt.legend(title='Import/Export & Shipping Method')
plt.show()

# 2. Line Plot
plt.figure(figsize=(10, 6))
# Here we'll use 'Date' to show a trend over time. Convert 'Date' to datetime if needed.
sdf['Date'] = pd.to_datetime(sdf['Date'])
# Grouping by date to calculate total value each day
daily_value = sdf.groupby('Date')['Value'].sum().reset_index()
sns.lineplot(data=daily_value, x='Date', y='Value')
plt.title('Line Plot of Daily Total Value')
plt.xlabel('Date')
plt.ylabel('Total Value')
plt.xticks(rotation=45)
plt.show()

# 3. Box Plot (Box-and-Whisker Plot)
plt.figure(figsize=(10, 6))
sns.boxplot(data=sdf, x='Category', y='Value', palette='Set2')
plt.title('Box Plot of Value by Category')
plt.xlabel('Category')
plt.ylabel('Value')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Visualization Analysis of Data Categorical

# %%
# Bar Chart for 'Shipping_Method'
plt.figure(figsize=(10, 6))
sns.countplot(data=sdf, x='Shipping_Method', palette='viridis')
plt.title('Count of Transactions by Shipping Method')
plt.xlabel('Shipping Method')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()


# Histogram for 'Quantity' with bins
plt.figure(figsize=(10, 6))
plt.hist(sdf['Quantity'], bins=30, color='skyblue', edgecolor='black')
plt.title('Distribution of Quantity')
plt.xlabel('Quantity')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)
plt.show()


# Pie Chart for 'Category'
category_counts = sdf['Category'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Proportion of Categories')
plt.axis('equal')  # Equal aspect ratio ensures that pie chart is circular.
plt.show()

# %%
facet_grid = px.bar(sdf, x='Country', y='Value', color='Shipping_Method',
                    facet_col='Import_Export', 
                    title="Trade Value by Country and Shipping Method (Imports vs Exports)",
                    labels={'Value': 'Trade Value'}, barmode='group')
facet_grid.show()


import numpy as np

heatmap_data = sdf[['Quantity', 'Value', 'Weight']]
correlation_matrix = heatmap_data.corr()

heatmap = px.imshow(correlation_matrix, text_auto=True, 
                    title="Correlation Between Quantity, Value, and Weight",
                    labels={'color': 'Correlation'})
heatmap.show()


sunburst_chart = px.sunburst(sdf, path=['Import_Export', 'Country', 'Category'], values='Value',
                             title="Breakdown of Product Categories by Country and Import/Export",
                             color='Value', hover_data=['Product'],
                             color_continuous_scale='RdBu')
sunburst_chart.show()

box_plot = px.box(sdf, x='Category', y='Value', color='Import_Export',
                  title="Trade Value by Product Category (Imports vs Exports)",
                  points='all',  # Displays all data points
                  labels={'Value': 'Trade Value'})
box_plot.show()


histogram = px.histogram(sdf, x='Value', color='Import_Export', 
                         nbins=50, title="Distribution of Trade Values (Imports vs Exports)", 
                         labels={'Value': 'Trade Value'}, 
                         marginal='box', # Adds box plot for deeper distribution insight
                         hover_data=['Country', 'Product'])
histogram.show()

choropleth_map = px.choropleth(sdf, locations='Country', locationmode='country names',
                               color='Value', hover_name='Country', 
                               title="Global Distribution of Export/Import by Country",
                               color_continuous_scale=px.colors.sequential.Plasma)
choropleth_map.show()


scatter_plot = px.scatter(sdf, x='Quantity', y='Value', color='Category', 
                          size='Weight', hover_data=['Country', 'Product'], 
                          title="Relationship between Quantity and Value")
scatter_plot.show()


pie_chart = px.pie(sdf, names='Import_Export', values='Value', 
                   title='Distribution of Exports vs Imports')
pie_chart.show()


sdf['Date'] = pd.to_datetime(sdf['Date'], format='%d-%m-%Y')
line_chart = px.line(sdf.groupby(['Date', 'Import_Export']).sum().reset_index(), 
                     x='Date', y='Value', color='Import_Export', 
                     title="Trend of Total Trade Value Over Time",
                     labels={'Value': 'Total Value'})
line_chart.show()

import plotly.express as px

bar_chart = px.bar(sdf, x='Country', y='Value', color='Import_Export', 
                   title="Total Import/Export Value by Country", 
                   labels={'Value': 'Total Value'}, 
                   barmode='group')
bar_chart.show()
